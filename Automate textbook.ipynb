# %%
#Ch1: Python basics

#input() allows you to type something in
myname = input()

# %%
#ch 1
#cool use of int
print('What is your age?') # ask for their age
myAge = input()
print('You will be ' + str(int(myAge) + 1) + ' in a year.')
# Out:
# What is your age?
# 21
# You will be 22 in a year.

# %%
#Ch2: Flow control

#While statement
spam = 0
while spam < 5:
    print('Hello, world.')
    spam = spam + 1
# Out:
# Hello, world.
# Hello, world.
# Hello, world.
# Hello, world.
# Hello, world.

# %%
#Ch 2
#break statement
#Without break statement, it will print('Thank you!') after "your name" but continue to ask
while True:
    print('Please type your name.')
    name = input()
    if name == 'your name':
        break
print('Thank you!')

#"If the execution reaches a break statement, it immediately
# exits the while loop’s clause"
# Out:
# Please type your name.
# chad
# Please type your name.
# chad
# Please type your name.
# chad
# Please type your name.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# /anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     466         """
# --> 467         parts = [self.recv(flags, copy=copy, track=track)]
# ...

# %%
#Ch 2
#Continue Statement

while True:
    print('Who are you?')
    name = input()
    if name != 'Joe':
        continue
    print('Hello, Joe. What is the password? (It is a fish.)')
    password = input()
    if password == 'swordfish':
        break

print('Access granted.')


#"When the program execution reaches a continue statement, the program execution
# immediately jumps back to the start of the loop and reevaluates the loop’s
# condition. (This is also what happens when the execution reaches the end
# of the loop.)"
# Out:
# Who are you?
# Chad
# Who are you?
# Joe
# Hello, Joe. What is the password? (It is a fish.)
# jellyfishhh
# Who are you?
# hi
# Who are you?
# you
# Who are you?
# Joe
# Hello, Joe. What is the password? (It is a fish.)
# swordfish
# Access granted.

# %%
#Ch 2
#Continue Statement
#Doing above function without returning to who are you

while True:
    print('Who are you?')
    name = input()
    if name == 'Joe':
        while True:
            print('Hello, Joe. What is the password? (It is a fish.)')
            password = input()
            if password == 'swordfish':
                break
        break
        

print('Access granted.')


#"When the program execution reaches a continue statement, the program execution
# immediately jumps back to the start of the loop and reevaluates the loop’s
# condition. (This is also what happens when the execution reaches the end
# of the loop.)"
# Out:
# Who are you?
# chad
# Who are you?
# chad
# Who are you?
# chda
# Who are you?
# chadf
# Who are you?
# Joe
# Hello, Joe. What is the password? (It is a fish.)
# swor
# Hello, Joe. What is the password? (It is a fish.)
# swordfish
# Access granted.

# %%
#Ch2
#For loop and range (sum first 100 numbers)

total = 0
for num in range(101):
    total = total + num
print(total)
# Out:
# 5050

# %%
#Ch2
#Steps and reverses; for loops

for i in range(0, 10, 2): 
    print(i)
    
print("\n")

for i in range(5, -1, -1):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
#
#
# 5
# 4
# 3
# 2
# 1
# 0

# %%
#ch 2
#(NOT IMPORTANT add to end)
#
#
#to quit a system on IDLE 
import sys

while True:
    print('Type exit to exit.')
    response = input()
    if response == 'exit':
        sys.exit()
    print('You typed ' + response + '.')
# Out:
# Type exit to exit.
# ext
# You typed ext.
# Type exit to exit.
# exit
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
#Ch 3 Functions

#The none type
fullsend = print("hi boiii")
None == fullsend
# Out:
# hi boiii
# True

# %%
#Ch3 
#print variations

print('Hello', end=' ')
print('World')
print("\n")
print('cats', 'dogs', 'mice')
print("\n")
print('cats', 'dogs', 'mice', sep=',')
# Out:
# Hello World
#
#
# cats dogs mice
#
#
# cats,dogs,mice

# %%
#Ch3
#local scopes dont change other vars

def spam():
    eggs = 99
    bacon()
    print(eggs)
def bacon():
    ham = 101
    eggs = 0
spam()

print("\n")
print("\n")
def spam():
    eggs = 'spam local'
    print(eggs) # prints 'spam local'
def bacon():
    eggs = 'bacon local'
    print(eggs) # prints 'bacon local'
    spam()
    print(eggs) # prints 'bacon local'
eggs = 'global'
bacon()
print(eggs) # prints 'global'

print("\n There are 3 eggs: one in global, one in spam(), and one in bacon()")
# Out:
# 99
#
#
#
#
# bacon local
# spam local
# bacon local
# global
#
#  There are 3 eggs: one in global, and one in spam() and bacon()

# %%
#Ch 3
#global Statement to change global variable from w/n f

def spam():
    global eggs
    eggs = 'spam'
    
eggs = 'global'
print(eggs)
spam()
print(eggs)
# Out:
# global
# spam

# %%
42/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-52-892840ca7299> in <module>
# ----> 1 42/0
#
# ZeroDivisionError: division by zero

# %%
#Ch 3
#try and except when running into potential errors
#example of dividing by 0, which returns error and stops rest of f


def spam(divideBy):
    try:
        return 42 / divideBy
    except ZeroDivisionError: #look above
        print('Error: Invalid argument.')
        
print(spam(2))
print(spam(12))
print(spam(0))
print(spam(1))
# Out:
# 21.0
# 3.5
# Error: Invalid argument.
# None
# 42.0

# %%
# Ch 3

import random

def play_game():
    secretNumber = random.randint(1, 20)
    print('I am thinking of a number between 1 and 20.')
    # Ask the player to guess 6 times.
    print("Guess my number")
    for guessesTaken in range(1, 7): 
        guess = input()
        if int(guess) == secretNumber:
            print("Great job!")
            break
        elif int(guess) < secretNumber:
            print("Your guess is too small")
        else:
            print("Your guess is too large")
    if int(guess) != secretNumber:
        print("Nice try")
    else:
        print("You guessed in " + str(guessesTaken) + " tries!")

# %%
play_game()
# Out:
# I am thinking of a number between 1 and 20.
# Guess my number
# 10
# Your guess is too large
# 5
# Your guess is too large
# 3
# Great job!
# You guessed in 3 tries!

# %%
#Ch 3

def collatz(number):
    print(number)
    while number != 1:
        if number % 2 == 0:
            number //= 2
            print(number)
        else:
            number *= 3 
            number += 1
            print(number)

# %%
collatz(2)
print()
collatz(3)
# Out:
# 2
# 1
#
# 3
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
collatz("hi")
# Out:
# hi
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-d92280bfea9c> in <module>
# ----> 1 collatz("hi")
#
# <ipython-input-96-ec25beeed3c1> in collatz(number)
#       4     print(number)
#       5     while number != 1:
# ----> 6         if number % 2 == 0:
#       7             number //= 2
#       8             print(number)
#
# TypeError: not all arguments converted during string formatting

# %%
#Ch4 Lists

#Lists of lists and indexing
spam = [['cat', 'bat'], [10, 20, 30, 40, 50]]

print(spam[0])

print(spam[0][1])

print(spam[-1])

print(spam[-1][-1])

print(spam[1][1:3])

print(spam[1][0:-1]) #all but last

print(spam[1][0:2]) #index 0, 1

print(spam[1][2:]) #index 2, 3, 4
# Out:
# ['cat', 'bat']
# bat
# [10, 20, 30, 40, 50]
# 50
# [20, 30]
# [10, 20, 30, 40]
# [10, 20]
# [30, 40, 50]

# %%
#Ch4

#List concatenation, replication, and deletion

print([1, 2, 3] + ['A', 'B', 'C'])

print(['X', 'Y', 'Z'] * 3)

spam = [1, 2, 3]
spam += ['A', 'B', 'C']
print(spam)

del spam[2]
print(spam)
# Out:
# [1, 2, 3, 'A', 'B', 'C']
# ['X', 'Y', 'Z', 'X', 'Y', 'Z', 'X', 'Y', 'Z']
# [1, 2, 3, 'A', 'B', 'C']
# [1, 2, 'A', 'B', 'C']

# %%
#Ch4

#EX) Store the names of cats 
#Start with empty list then continue


catNames = []

while True:
    print("Enter name of cat " + str(len(catNames) + 1) + " (or press nothing to stop)")
    name = input()
    if name == "":
        break
    else:
        catNames += [str(name)]

for names in catNames:
    print(" " + names)

#OR may use (better if want to print out index too, like below)


# for i in range(len(catNames)):
#    print("Cat " + str(i + 1) + " is " + catNames[i])
# Out:
# Enter name of cat 1 (or press nothing to stop)
# hi
# Enter name of cat 2 (or press nothing to stop)
# heyy
# Enter name of cat 3 (or press nothing to stop)
#
#  hi
#  heyy

# %%
#Ch 4
#In and not in

print('howdy' in ['hello', 'hi', 'howdy', 'heyas'])

spam = ['hello', 'hi', 'howdy', 'heyas']
print('cat' not in spam)
print("cat" in spam)
# Out:
# True
# True
# False

# %%
#Ch 4
#Multiple assignment trick

cat = ['fat', 'black', 'loud']
size = cat[0]
color = cat[1]
disposition = cat[2]

#OR

size, color, disposition = cat

# %%
#Ch 4
#Filtering with index Method (returns ValueError if not in it)
# Note: if two same values in lists, returns first

spam = ['hello', 'hi', 'howdy', 'heyas']
spam.index("hello")
# Out:
# 0

# %%
#Ch 4
#Adding values with insert and assign Methods
#Removing values with remove Method
#Note: if two same values in list, remove only removes the first

spam = ['cat', 'dog', 'bat']
spam.append("moose")
print(spam)

spam.insert(1, 'chicken') #as index 1
print(spam)

spam.remove("dog") #ValueError if not in it
print(spam)
# Out:
# ['cat', 'dog', 'bat', 'moose']
# ['cat', 'chicken', 'dog', 'bat', 'moose']
# ['cat', 'chicken', 'bat', 'moose']

# %%
#Ch 4
#Sorting values with the sort Method
#Note: for characters, "Bob" seen as before "bangle" since uppercase go first
        # to go past this, use spam.sort(key=str.lower)

spam = [2, 5, 3.14, 1, -7]
spam.sort()
print(spam)

spam = ['ants', 'cats', 'dogs', 'badgers', 'elephants']
spam.sort()
print(spam)

spam.sort(reverse=True)
print(spam)
# Out:
# [-7, 1, 2, 3.14, 5]
# ['ants', 'badgers', 'cats', 'dogs', 'elephants']
# ['elephants', 'dogs', 'cats', 'badgers', 'ants']

# %%
#Ch 4
#Ex) Magic 8 ball 

import random

messages = ['It is certain',
'It is decidedly so',
'Yes definitely',
'Reply hazy try again',
'Ask again later',
'Concentrate and ask again',
'My reply is no',
'Outlook not so good',
'Very doubtful']

print(messages[random.randint(0, len(messages) - 1)])
# Out:
# Outlook not so good

# %%
#Format/style
#Go somewhere else

#To print something with many lines of code

print('Four score and seven ' + \
'years ago...')
# Out:
# Four score and seven years ago...

# %%
#Ch 4
# Character and Tuple indexing

# Character

name = "Sophie"
print(name[0])
print(name[2])
print("So" in name)

for i in name:
    print('* * * ' + i + ' * * *')

#Strings are immutable 

#To change, must do:
name = 'Sophie a cat'
print(name)
newName = name[0:7] + 'the' + name[8:12] #[0:7], [8:12] refer to characters we did NOT want to change
print(newName)

#or else you get error:
name = 'Sophie a cat'
name[8] = "the"
# Out:
# S
# p
# True
# * * * S * * *
# * * * o * * *
# * * * p * * *
# * * * h * * *
# * * * i * * *
# * * * e * * *
# Sophie a cat
# Sophie the cat
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-179-318a2856d2b6> in <module>
#      22 #or else you get error:
#      23 name = 'Sophie a cat'
# ---> 24 name[8] = "the"
#      25
#      26
#
# TypeError: 'str' object does not support item assignment

# %%
#Ch 4
#Tuples: Like lists, but immutable

eggs = ('hello', 42, 0.5)
print(eggs[0])

#When have one value, must have comma

#When have comma:
one_value = (40,)
print(one_value)
print(type(one_value))


#If do not have comma:
one_value = (40)
print(one_value)
print(type(one_value))


#Convert from list -> tuple and vica versa:
print(tuple(['cat', 'dog', 5]))
print(list(("cat", "dog", 2)))

#Convert string to a list and vica versa:
print(list("Apple"))
x = list("Apple")
str_x = "".join(x)
print(str_x)
print(type(str_x))

spam = ['apples', 'bananas', 'tofu', 'cats']
str_spam = " and ".join(spam)
print(str_spam)

#TypeError when
eggs[1] = 99
# Out:
# hello
# (40,)
# <class 'tuple'>
# 40
# <class 'int'>
# ('cat', 'dog', 5)
# ['cat', 'dog', 2]
# ['A', 'p', 'p', 'l', 'e']
# Apple
# <class 'str'>
# apples and bananas and tofu and cats
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-205-b9b351971d68> in <module>
#      35
#      36 #TypeError when
# ---> 37 eggs[1] = 99
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Ch 4
#References in python: changes value right there

def eggs(someParameter):
    someParameter.append('Hello')
spam = [1, 2, 3]
print(spam)
eggs(spam)
print(spam)
# Out:
# [1, 2, 3]
# [1, 2, 3, 'Hello']

# %%
#Ch 4
#Copy module's copy() and deepcopy() functions
#Use deepcopy() if list has multiple lists inside

import copy
spam = ['A', 'B', 'C', 'D']
cheese = copy.copy(spam)
cheese[1] = 42

print(spam)

print(cheese)
# Out:
# ['A', 'B', 'C', 'D']
# ['A', 42, 'C', 'D']

# %%
#Ch 4
#printing project

grid = [['.', '.', '.', '.', '.', '.'],
['.', 'O', 'O', '.', '.', '.'],
['O', 'O', 'O', 'O', '.', '.'],
['O', 'O', 'O', 'O', 'O', '.'],
['.', 'O', 'O', 'O', 'O', 'O'],
['O', 'O', 'O', 'O', 'O', '.'],
['O', 'O', 'O', 'O', '.', '.'],
['.', 'O', 'O', '.', '.', '.'],
['.', '.', '.', '.', '.', '.']]

#want:
    
#..OO.OO..
#.OOOOOOO.
#.OOOOOOO.
#..OOOOO..
#...OOO...
#....O....


for i in range(len(grid[1])): #columns
    for j in range(len(grid)): #rows
        print(grid[j][i], end = "")
    print()
# Out:
# ..OO.OO..
# .OOOOOOO.
# .OOOOOOO.
# ..OOOOO..
# ...OOO...
# ....O....

# %%
print(len(grid))    # number rows/lists
print(len(grid[1])) # number columns
# Out:
# 9
# 6

# %%
#Ch5
#Dictionaries and structuring data

myCat = {'size': 'fat', 'color': 'gray', 'disposition': 'loud'}
print(myCat)
print(myCat['size'])

print()
spam = {12345: 'Luggage Combination', 42: 'The Answer'}
print(spam)
# Out:
# {'size': 'fat', 'color': 'gray', 'disposition': 'loud'}
# fat
#
# {12345: 'Luggage Combination', 42: 'The Answer'}

# %%
#Ch 5
#Dictionaries vs Lists

spam = ['cats', 'dogs', 'moose']
bacon = ['dogs', 'moose', 'cats']
print(spam == bacon) #order matters
print("Order Matters")


eggs = {'name': 'Zophie', 'species': 'cat', 'age': '8'}
ham = {'species': 'cat', 'age': '8', 'name': 'Zophie'}
print(eggs == ham) #order doesn't matter
# Out:
# False
# Order Matters
# True

# %%
#Ch 5
#Ex) Store data on friend's birthdays

birthdays = {'Alice': 'Apr 1', 'Bob': 'Dec 12', 'Carol': 'Mar 4'}

while True:
    print('Enter a name: (blank to quit)')
    name = input()
    if name == '':
        break
        
    if name in birthdays:
        print(birthdays[name] + ' is the birthday of ' + name)
    else:
        print('I do not have birthday information for ' + name)
        print('What is their birthday?')
        bday = input()
        birthdays[name] = bday
        print('Birthday database updated.')
# Out:
# Enter a name: (blank to quit)
# Alice
# Apr 1 is the birthday of Alice
# Enter a name: (blank to quit)
# Chad
# I do not have birthday information for Chad
# What is their birthday?
# Feb 18
# Birthday database updated.
# Enter a name: (blank to quit)
# bob
# I do not have birthday information for bob
# What is their birthday?
# Dec 12
# Birthday database updated.
# Enter a name: (blank to quit)
# bob
# Dec 12 is the birthday of bob
# Enter a name: (blank to quit)
# Bob
# Dec 12 is the birthday of Bob
# Enter a name: (blank to quit)
# BOB
# I do not have birthday information for BOB
# What is their birthday?
# DEC 12
# Birthday database updated.
# Enter a name: (blank to quit)

# %%
birthdays
# Out:
# {'Alice': 'Apr 1',
#  'Bob': 'Dec 12',
#  'Carol': 'Mar 4',
#  'Chad': 'Feb 18',
#  'bob': 'Dec 12',
#  'BOB': 'DEC 12'}

# %%
#Ch 5
#The keys(), values(), and items() Methods

spam = {'color': 'red', 'age': 42}

for v in spam.values():
    print(v)
    
print()
    
for k in spam.keys():
    print(k)

print()

for i in spam.items(): #Tuple
    print(i) 
    
print()

for k, v in spam.items(): #Mutiple assignment method
    print('Key: ' + k + ' Value: ' + str(v))

print()

#Keys/Values -> List

x = spam.keys()
print(list(spam.keys()))
# Out:
# red
# 42
#
# color
# age
#
# ('color', 'red')
# ('age', 42)
#
# Key: color Value: red
# Key: age Value: 42
#
# ['color', 'age']

# %%
#Ch 5
#Checking Whether a Key or Value Exists in a Dictionary

print("color" in spam) #default is .keys()
print('Zophie' in spam.values())

#The get() Method
#Two args: key and value if key not in
#Really good when doing things where unsure if it is in: instead of doing picnicItems['eggs'] (leads to error)

picnicItems = {'apples': 5, 'cups': 2}
print('I am bringing ' + str(picnicItems.get('cups', 0)) + ' cups.')
print('I am bringing ' + str(picnicItems.get('eggs', 0)) + ' eggs.')

#The setdefault() Method

#Executes 
#   spam = {'name': 'Pooka', 'age': 5}
#   if 'color' not in spam:
#        spam['color'] = 'black'

spam = {'name': 'Pooka', 'age': 5}
spam.setdefault('color', 'black') #Not in there 
print(spam)

spam.setdefault('color', 'white') #In there so stays same
print(spam)

spam["color"] = 'white'
print(spam)

#Ex) Count occurance of letter in string
message = 'It was a bright cold day in April, and the clocks were striking thirteen.'
count = {}
for character in message:
    count.setdefault(character, 0)
    count[character] = count[character] + 1
    
print(count)
# Out:
# True
# False
# I am bringing 2 cups.
# I am bringing 0 eggs.
# {'name': 'Pooka', 'age': 5, 'color': 'black'}
# {'name': 'Pooka', 'age': 5, 'color': 'black'}
# {'name': 'Pooka', 'age': 5, 'color': 'white'}
# {'I': 1, 't': 6, ' ': 13, 'w': 2, 'a': 4, 's': 3, 'b': 1, 'r': 5, 'i': 6, 'g': 2, 'h': 3, 'c': 3, 'o': 2, 'l': 3, 'd': 3, 'y': 1, 'n': 4, 'A': 1, 'p': 1, ',': 1, 'e': 5, 'k': 2, '.': 1}

# %%
#Ch 5
#Pretty printing (pprint module) for dicts

import pprint
message = 'It was a bright cold day in April, and the clocks were striking thirteen.'
count = {}
for character in message:
    count.setdefault(character, 0)
    count[character] = count[character] + 1
    
pprint.pprint(count)


print()
print(pprint.pformat(count)) #same as pprint.pprint

print()
pprint.pformat(count) #as string
# Out:
# {' ': 13,
#  ',': 1,
#  '.': 1,
#  'A': 1,
#  'I': 1,
#  'a': 4,
#  'b': 1,
#  'c': 3,
#  'd': 3,
#  'e': 5,
#  'g': 2,
#  'h': 3,
#  'i': 6,
#  'k': 2,
#  'l': 3,
#  'n': 4,
#  'o': 2,
#  'p': 1,
#  'r': 5,
#  's': 3,
#  't': 6,
#  'w': 2,
#  'y': 1}
#
# {' ': 13,
#  ',': 1,
#  '.': 1,
#  'A': 1,
#  'I': 1,
#  'a': 4,
#  'b': 1,
#  'c': 3,
#  'd': 3,
#  'e': 5,
#  'g': 2,
#  'h': 3,
#  'i': 6,
#  'k': 2,
#  'l': 3,
#  'n': 4,
#  'o': 2,
#  'p': 1,
#  'r': 5,
#  's': 3,
#  't': 6,
#  'w': 2,
#  'y': 1}
# "{' ': 13,\n ',': 1,\n '.': 1,\n 'A': 1,\n 'I': 1,\n 'a': 4,\n 'b': 1,\n 'c': 3,\n 'd': 3,\n 'e': 5,\n 'g': 2,\n 'h': 3,\n 'i': 6,\n 'k': 2,\n 'l': 3,\n 'n': 4,\n 'o': 2,\n 'p': 1,\n 'r': 5,\n 's': 3,\n 't': 6,\n 'w': 2,\n 'y': 1}"

# %%
#Ch 5
#Ex) Tic Tac Toe
#http://inventwithpython.com/chapter10.html for more


theBoard = {'top-L': ' ', 'top-M': ' ', 'top-R': ' ',
'mid-L': ' ', 'mid-M': ' ', 'mid-R': ' ',
'low-L': ' ', 'low-M': ' ', 'low-R': ' '}

def printBoard(board):
    print(board['top-L'] + '|' + board['top-M'] + '|' + board['top-R'])
    print('-+-+-')
    print(board['mid-L'] + '|' + board['mid-M'] + '|' + board['mid-R'])
    print('-+-+-')
    print(board['low-L'] + '|' + board['low-M'] + '|' + board['low-R'])

turn = 'X'
for i in range(9):
    printBoard(theBoard)
    print('Turn for ' + turn + '. Move on which space?')
    print("Options are: ", end="")
    print(list(theBoard.keys()))
    move = input()
    theBoard[move] = turn
    if turn == 'X':
        turn = 'O'
    else:
        turn = 'X'
printBoard(theBoard)
# Out:
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for X. Move on which space?
# Options are: ['top-L', 'top-M', 'top-R', 'mid-L', 'mid-M', 'mid-R', 'low-L', 'low-M', 'low-R']
# top-L
# X| |
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for O. Move on which space?
# Options are: ['top-L', 'top-M', 'top-R', 'mid-L', 'mid-M', 'mid-R', 'low-L', 'low-M', 'low-R']
# top-R
# X| |O
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for X. Move on which space?
# Options are: ['top-L', 'top-M', 'top-R', 'mid-L', 'mid-M', 'mid-R', 'low-L', 'low-M', 'low-R']
# mid-M
# X| |O
# -+-+-
#  |X|
# -+-+-
#  | |
# Turn for O. Move on which space?
# Options are: ['top-L', 'top-M', 'top-R', 'mid-L', 'mid-M', 'mid-R', 'low-L', 'low-M', 'low-R']
# low-R
# X| |O
# -+-+-
#  |X|
# -+-+-
#  | |O
# Turn for X. Move on which space?
# Options are: ['top-L', 'top-M', 'top-R', 'mid-L', 'mid-M', 'mid-R', 'low-L', 'low-M', 'low-R']
# mid-L
# X| |O
# -+-+-
# X|X|
# -+-+-
#  | |O
# Turn for O. Move on which space?
# ...

# %%
#Ch 5
#Nested Dictionaries and Lists
#Ex)

allGuests = {'Alice': {'apples': 5, 'pretzels': 12},
'Bob': {'ham sandwiches': 3, 'apples': 2},
'Carol': {'cups': 3, 'apple pies': 1}}

def totalBrought(guests, item):
    numBrought = 0
    for k, v in guests.items():
        numBrought += v.get(item, 0)
    return numBrought

print('Number of things being brought:')
print(' - Apples ' + str(totalBrought(allGuests, 'apples')))
print(' - Cups ' + str(totalBrought(allGuests, 'cups')))
print(' - Cakes ' + str(totalBrought(allGuests, 'cakes')))
print(' - Ham Sandwiches ' + str(totalBrought(allGuests, 'ham sandwiches')))
print(' - Apple Pies ' + str(totalBrought(allGuests, 'apple pies')))
# Out:
# Number of things being brought:
#  - Apples 7
#  - Cups 3
#  - Cakes 0
#  - Ham Sandwiches 3
#  - Apple Pies 1

# %%
#Ch 5
#Project: Fantasy game inventory

stuff = {'rope': 1, 'torch': 6, 'gold coin': 42, 'dagger': 1, 'arrow': 12}

def displayInventory(inventory):
    print("Inventory:")
    item_total = 0
    for k, v in inventory.items():
        print(str(v) + ' ' + k)
        item_total += v
    print("Total number of items: " + str(item_total))
    
displayInventory(stuff)

#Vanguished dragon loot rep'd as list

dragonLoot = ['gold coin', 'dagger', 'gold coin', 'gold coin', 'ruby']

def addToInventory(inventory, added_items):
    """Combine a list of loot with an inventory."""
    for loot in added_items:
        inventory.setdefault(loot, 0)
        inventory[loot] += 1
    return(inventory)

    
inv = {'gold coin': 42, 'rope': 1}
dragonLoot = ['gold coin', 'dagger', 'gold coin', 'gold coin', 'ruby']
inv = addToInventory(inv, dragonLoot)
displayInventory(inv)
# Out:
# Inventory:
# 1 rope
# 6 torch
# 42 gold coin
# 1 dagger
# 12 arrow
# Total number of items: 62
# Inventory:
# 45 gold coin
# 1 rope
# 1 dagger
# 1 ruby
# Total number of items: 48

# %%
#Ch6 Manipulating strings

#List of escape characters
#\' = single quote
#\" = double quote
#\t = tab
#\n = newline
#\\ = backslash

print("""Dear Alice,

Eve's cat sucks

Sincerely""")

"""this is a multiline

comment
cool!
"""
# Out:
# Dear Alice,
#
# Eve's cat sucks
#
# Sincerely

# %%
#Ch 6
#in

print("HELLO" in "Hello")
print("HELLO" not in "Hello")
# Out:
# False
# True

# %%
#Ch 6
#Methods
spam = "Hello there"
spam = spam.upper()
print(spam)
spam = spam.lower()
print(spam)
spam = "Hello there"

print(spam.islower()) #True
print(spam.isupper()) #False

print('abc123'.islower())
print("123".islower())

# Great for case-insensitive things
def question():
    print("How are you?")
    feeling = input()
    if feeling.lower() == 'great':
        print("Same")
    else:
        print("Sorry to hear that")
        
question()
# Out:
# HELLO THERE
# hello there
# False
# False
# True
# False
# How are you?
# GReAt
# Same

# %%
#Ch 6
#The isX methods and starts/endswith()

spam = "Hello World"
print(spam.isalpha()) #True if no blanks/spaces
print(spam.isalnum()) #True if only letters & numbers & no blanks/spaces
print(spam.isdecimal()) #True if string only numbers and not blank
print(spam.isspace()) #True if only spaces, tabs, and new lines, and not blank
print(spam.istitle()) #True if words that are upper case followed be lower case ones

print(spam.startswith("Hello"))
print(spam.endswith('orld'))
# Out:
# False
# False
# False
# False
# True
# True
# True

# %%
#Ch 6
#Join and split methods
print(', '.join(['cats', 'dogs', 'bats']))
print(' '.join(['My', 'name', 'is', 'Chad']))

print("My name is Chad".split())
print("MyABCnameABCisABCChad".split("ABC"))

spam = """Dear Alice
What's up? I miss you
There is something you need to know
okay?

Do not drink the potion.

Best,
Chad"""

spam.split('\n')
# Out:
# cats, dogs, bats
# My name is Chad
# ['My', 'name', 'is', 'Chad']
# ['My', 'name', 'is', 'Chad']
# ['Dear Alice',
#  "What's up? I miss you",
#  'There is something you need to know',
#  'okay?',
#  '',
#  'Do not drink the potion.',
#  '',
#  'Best,',
#  'Chad']

# %%
#Ch 6
#Justifying Text

print("Hello")
print("Hello".rjust(10)) #5 spaces right-moved
print("Hello".rjust(20)) #15 spaces right-moved

print("\n")

print("Hello")
print("Hello".center(10)) 
print("Hello".center(20, "*")) 

print()
## Good to print tabular data that has correct spacing

def printPicnic(itemsDict, leftWidth, rightWidth):
    print('PICNIC ITEMS'.center(leftWidth + rightWidth, '-'))
    for k, v in itemsDict.items():
        print(k.ljust(leftWidth, '.') + str(v).rjust(rightWidth))
        
picnicItems = {'sandwiches': 4, 'apples': 12, 'cups': 4, 'cookies': 8000}
printPicnic(picnicItems, 12, 5)
printPicnic(picnicItems, 20, 6)
# Out:
# Hello
#      Hello
#                Hello
#
#
# Hello
#   Hello
# *******Hello********
#
# ---PICNIC ITEMS--
# sandwiches..    4
# apples......   12
# cups........    4
# cookies..... 8000
# -------PICNIC ITEMS-------
# sandwiches..........     4
# apples..............    12
# cups................     4
# cookies.............  8000

# %%
#Ch 6
# Removing Whitespace with strip(), rstrip(), and lstrip()

spam = ' Hello World '
print(spam)
print(spam.strip())
print()
print(spam.lstrip())
print()
print(spam.rstrip())
print()
spam = 'SpamSpamBaconSpamEggsSpamSpam'
print(spam.strip('ampS'))
# Out:
#  Hello World
# Hello World
#
# Hello World
#
#  Hello World
#
# BaconSpamEggs

# %%
#Ch 6
#Copying and Pasting Strings with the pyperclip Module

import pyperclip
pyperclip.copy('Hello world!')
pyperclip.paste()
# Out:
# 'Hello world!'

# %%
#Ch 7 (Part 2: Automating tasks)
#Pattern matching with regular expressions

#Ex) Is it a phone number

def isPhoneNumber(text):
    if len(text) != 12:
        return False
    for i in range(0, 3):
        if not text[i].isdecimal():
            return False
    if text[3] != '-':
        return False
    for i in range(4, 7):
        if not text[i].isdecimal():
            return False
    if text[7] != '-':
        return False
    for i in range(8, 12):
        if not text[i].isdecimal():
            return False
    return True

print(isPhoneNumber("222-331-1523"))
print(isPhoneNumber("222-331-15223"))
print(isPhoneNumber("222-owerar-15223"))

def findnumberintext(text):
    for i in range(len(text)):
        chunk = text[i:i+12]
        if isPhoneNumber(chunk):
            print("Phone number found: " + chunk)
    print("Finished")
    
print(findnumberintext("I had a great time tonight , my number is 222-331-1523. Awesome! Mine is 123-456-1234"))
print(findnumberintext("222-331-15223")) #this also catches it tho
print(findnumberintext("222-owerar-15223"))
# Out:
# True
# False
# False
# Phone number found: 222-331-1523
# Phone number found: 123-456-1234
# Finished
# None
# Phone number found: 222-331-1522
# Finished
# None
# Finished
# None

# %%
#Ch 7
#Pattern matching with module re
import re
phoneNumRegex = re.compile(r'\d\d\d-\d\d\d-\d\d\d\d') #r means raw
mo = phoneNumRegex.search("My Number is 415-222-1315")
print("Phone number found: " + mo.group())
print(mo)
# Can also test on https://www.regexpal.com/
# Out:
# Phone number found: 415-222-1315
# <re.Match object; span=(13, 25), match='415-222-1315'>

# %%
phoneNumRegex = re.compile(r'(\d\d\d)-(\d\d\d-\d\d\d\d)')
mo = phoneNumRegex.search("My Number is 415-222-1315")
print(mo.group(1))
print(mo.group(2))
print(mo.group(0))
areaCode, mainNumber = mo.groups()
print(areaCode)
print(mainNumber)
# Out:
# 415
# 222-1315
# 415-222-1315
# 415
# 222-1315

# %%
#Ch 7
#The findall() Method

phoneNumRegex = re.compile(r'\d\d\d-\d\d\d-\d\d\d\d')
phoneNumRegex.findall("Cell: 513-221-1421 Work: 141-214-7751")
# Out:
# ['513-221-1421', '141-214-7751']

# %%
#Ch 7
#Character Classes

#\d = any digit from 0 to 9
#\D = any character not a digit 0 to 9
#\w = Any letter, numeric digit, or the underscore character.
         # (Think of this as matching “word” characters.)
#\W = Any character that is not a letter, numeric digit, or the underscore character.
#\s = Any space, tab, or newline character. 
        #(Think of this as matching “space” characters.)
#\S = Any character that is not a space, tab, or newline.


#Can make your own Character class
vowelRegex = re.compile(r'[aeiouAEIOU]') #(r'[^aeiouAEIOU]) for NOT those
vowelRegex.findall('RoboCop eats baby food. BABY FOOD.')
# Out:
# ['o', 'o', 'o', 'e', 'a', 'a', 'o', 'o', 'A', 'O', 'O']

# %%
# ^ You can also use the caret symbol (^) at the start of a regex 
# to indicate that a match must occur at the beginning of the searched 
# text. Likewise, you can put a dollar sign ($) at the end of the 
# regex to indicate the string must end with this regex pattern. 
# And you can use the ^ and $ together to indicate that the 
# entire string must match the regex—that is, it’s not enough for a
# match to be made on some subset of the string.

endsWithNumber = re.compile(r'\d$') #strings ending in decimal
print(endsWithNumber.search('Your number is 42').group())
wholeStringIsNum = re.compile(r'^\d+$')
print(wholeStringIsNum.search('1234567890').group())

# The . (or dot) character in a regular expression is called a 
#wildcard and will match any character except for a newline.

atRegex = re.compile(r'.at')
print(atRegex.findall('The cat in the hat sat on the flat mat.')) 
#Notice lat
atRegex = re.compile(r'..at')
print(atRegex.findall('The cat in the hat sat on the flat mat.'))

#To match everything, use (.*)
nameRegex = re.compile(r'First Name: (.*) Last Name: (.*)')
mo = nameRegex.search('First Name: Al Last Name: Sweigart')
print(mo.group(1))
print(mo.group(2))
# Out:
# 2
# 1234567890
# ['cat', 'hat', 'sat', 'lat', 'mat']
# [' cat', ' hat', ' sat', 'flat', ' mat']
# Al
# Sweigart

# %%
#Ch 8
#Reading and Writing files

#Ch 9
#Organizing files

# %%
#Ch 10
#Debugging
#Raising Exceltpions
def boxPrint(symbol, width, height):
    if len(symbol) != 1:
        raise Exception('Symbol must be a single character string.')
    if width <= 2:
        raise Exception('Width must be greater than 2.')
    if height <= 2:
        raise Exception('Height must be greater than 2.')
    print(symbol * width)
    for i in range(height - 2):
        print(symbol + (' ' * (width - 2)) + symbol)
    print(symbol * width)

for sym, w, h in (('*', 4, 4), ('O', 20, 5), ('x', 1, 3), ('ZZ', 3, 3)):
    try:
        boxPrint(sym, w, h)
    except Exception as err:
        print('An exception happened: ' + str(err))
# Out:
# ****
# *  *
# *  *
# ****
# OOOOOOOOOOOOOOOOOOOO
# O                  O
# O                  O
# O                  O
# OOOOOOOOOOOOOOOOOOOO
# An exception happened: Width must be greater than 2.
# An exception happened: Symbol must be a single character string.

# %%
#Chapter 10
#Assertions 
"""An assertion is a sanity check to make sure your code isn’t doing something
obviously wrong. These sanity checks are performed by assert statements. If
the sanity check fails, then an AssertionError exception is raised. In code, an
assert statement consists of the following:
• The assert keyword
• A condition (that is, an expression that evaluates to True or False)
• A comma
• A string to display when the condition is False"""
podBayDoorStatus = 'open'
assert podBayDoorStatus == 'open', 'The pod bay doors need to be open.'
podBayDoorStatus = 'I\'m sorry, Dave. I\'m afraid I cant do that.'''
assert podBayDoorStatus == 'open', 'The pod bay doors need to be "open".'

"""In plain English, an assert statement says, “I assert that this condition
holds true, and if not, there is a bug somewhere in the program.”"""
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-45b33ea60c7b> in <module>
#      12 assert podBayDoorStatus == 'open', 'The pod bay doors need to be open.'
#      13 podBayDoorStatus = 'I\'m sorry, Dave. I\'m afraid I cant do that.'''
# ---> 14 assert podBayDoorStatus == 'open', 'The pod bay doors need to be "open".'
#      15
#      16 """In plain English, an assert statement says, “I assert that this condition
#
# AssertionError: The pod bay doors need to be "open".

# %%
#Chapter 10
#Example of Assertions
market_2nd = {'ns': 'green', 'ew': 'red'}
mission_16th = {'ns': 'red', 'ew': 'green'}
def switchLights(stoplight):
    for key in stoplight.keys():
        if stoplight[key] == 'green':
            stoplight[key] = 'yellow'
        elif stoplight[key] == 'yellow':
            stoplight[key] = 'red'
        elif stoplight[key] == 'red':
            stoplight[key] = 'green'
        assert 'red' in stoplight.values(), 'Neither light is red! ' + str(stoplight)
            
switchLights(market_2nd)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-53957654b7d0> in <module>
#      13         assert 'red' in stoplight.values(), 'Neither light is red! ' + str(stoplight)
#      14
# ---> 15 switchLights(market_2nd)
#
# <ipython-input-19-53957654b7d0> in switchLights(stoplight)
#      11         elif stoplight[key] == 'red':
#      12             stoplight[key] = 'green'
# ---> 13         assert 'red' in stoplight.values(), 'Neither light is red! ' + str(stoplight)
#      14
#      15 switchLights(market_2nd)
#
# AssertionError: Neither light is red! {'ns': 'yellow', 'ew': 'green'}

# %%
#Chapter 10
#Loggging (using print statements)
import logging
logging.basicConfig(level=logging.DEBUG, format=' %(asctime)s - %(levelname)s- %(message)s')

# %%
import logging
logging.basicConfig(level=logging.DEBUG, format=' %(asctime)s - %(levelname)s - %(message)s')
logging.debug('Start of program')
def factorial(n):
    logging.debug('Start of factorial(%s%%)' % (n))
    total = 1
    for i in range(n + 1):
        total *= i #since i starts at 0!!
        logging.debug('i is ' + str(i) + ', total is ' + str(total))
    logging.debug('End of factorial(%s%%)' % (n))
    return total
print(factorial(5))
logging.disable(logging.CRITICAL) # to NOT show the debugging
logging.debug('End of program')
# Out:
# 0

# %% [markdown]
# #Chapter 10
# #Logging levels.
# ![](10_12.png)
# ![](10_11.png)

# %%
#Chapter 11 Web Scraping
#webbrowser module
"""This module opens a browser to a specific page

As long as you have a URL, the webbrowser module lets users cut out the step
of opening the browser and directing themselves to a website. Other programs
could use this functionality to do the following:
• Open all links on a page in separate browser tabs.
• Open the browser to the URL for your local weather.
• Open several social network sites that you regularly check.
"""
import webbrowser
webbrowser.open('https://inventwithpython.com/')
# Out:
# True

# %% [markdown]
# #Chapter 11
# #step 1: figure out the URL
# ![](11_1.png)
#
# This takes you to that address in google!
#
# When we run mapit 870 Valencia St, San Francisco, CA 94110 into the command line, the sys.argv variable will contain this list value:
# ['mapIt.py', '870', 'Valencia', 'St, ', 'San', 'Francisco, ', 'CA', '94110']

# %%
#Chapter 11
#Downloading Files from the Web with the requests Module
import requests
#Downloading a Web Page with the requests.get() Function
res = requests.get('https://www.gutenberg.org/cache/epub/1112/pg1112.txt') 
print(res.status_code == requests.codes.ok)

print(len(res.text)) #how many characters long the txt file is

print(res.text[:250])

#Checking for errors
res = requests.get('http://inventwithpython.com/page_that_does_not_exist')
#res.raise_for_status() #HTTPError
try:
    res.raise_for_status()
except Exception as exc:
    print('There was a problem: %s' % (exc))
# Out:
# True
# 178981
# ﻿The Project Gutenberg EBook of Romeo and Juliet, by William Shakespeare
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Proje
# There was a problem: 404 Client Error: Not Found for url: http://inventwithpython.com/page_that_does_not_exist

# %%
#Chapter 11
#cont. Downloading Files from the Web with the requests Module
import requests
res = requests.get('http://www.gutenberg.org/cache/epub/1112/pg1112.txt')
res.raise_for_status()
playFile = open('RomeoAndJuliet.txt', 'wb')
for chunk in res.iter_content(100000): #HOW MANY BYTES PER CHUNK
    playFile.write(chunk)
playFile.close()
#learn more here: http://requests.readthedocs.org/.

# %%
#Chapter 11
#HTML 
#Continue later
"""Resources for Learning HTML
Hypertext Markup Language (HTML) is the format that web pages are written
in. This chapter assumes you have some basic experience with HTML, but
if you need a beginner tutorial, I suggest one of the following sites:
• http://htmldog.com/guides/html/beginner/
• http://www.codecademy.com/tracks/web/
• https://developer.mozilla.org/en-US/learn/html/"""

# %%
#Chapter 12: Working with Excel Spreadsheets
import openpyxl
wb = openpyxl.load_workbook('example.xlsx')
type(wb)
# Out:
# openpyxl.workbook.workbook.Workbook

# %% [markdown]
# #Chapter 12:
# ![](12_1.png)

# %%
#Chapter 12
#Getting Sheets from the Workbook
wb.get_sheet_names()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   This is separate from the ipykernel package so we can avoid doing imports until
# ['Sheet1', 'Sheet2', 'Sheet3']

# %%
sheet3 = wb.get_sheet_by_name('Sheet3')
type(sheet3)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   """Entry point for launching an IPython kernel.
# openpyxl.worksheet.worksheet.Worksheet

# %%
sheet3.title
# Out:
# 'Sheet3'

# %%
another_sheet = wb.get_active_sheet()
another_sheet #Sheet 1.
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_active_sheet (Use the .active property).
#   """Entry point for launching an IPython kernel.
# <Worksheet "Sheet1">

# %%
#Getting Cells from the Sheets
sheet1 = wb.get_sheet_by_name('Sheet1')
sheet1['A1']
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
# <Cell 'Sheet1'.A1>

# %%
sheet1['A1'].value
# Out:
# datetime.datetime(2015, 4, 5, 13, 34, 2)

# %%
c = sheet1['b1']
print(c.value)
print()
print("Row " + str(c.row) + ', Column ' + c.column + 
      ' is ' + c.value)
print()
print('Cell ' + c.coordinate + ' is ' + c.value)
print()
sheet1['c1'].value
# Out:
# Apples
#
# Row 1, Column B is Apples
#
# Cell B1 is Apples
# 73

# %%
#Iterate over excel's rows and columns!!
sheet1.cell(row=1, column=2)
print(sheet1.cell(row=1, column=2).value)
print()
for i in range(1, 8, 2): #starts at 1, not 0, for first col/row
    print(i, sheet1.cell(row=i, column=2).value)
# Out:
# Apples
#
# 1 Apples
# 3 Pears
# 5 Apples
# 7 Strawberries

# %%
#Chapter 12
#Converting Between Column Letters and Numbers
import openpyxl
try: 
    from openpyxl.cell import get_column_letter, column_index_from_string
except ImportError:
    from openpyxl.utils import get_column_letter, column_index_from_string
print(get_column_letter(1))
print()
print(get_column_letter(27))
print()
print(column_index_from_string('A'))
print()
print(column_index_from_string('AA'))
# Out:
# A
#
# AA
#
# 1
#
# 27

# %%
#Chapter 12
#Getting Rows and Columns from the Sheets
tuple(sheet1['A1':'C3'])
# Out:
# ((<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>, <Cell 'Sheet1'.C1>),
#  (<Cell 'Sheet1'.A2>, <Cell 'Sheet1'.B2>, <Cell 'Sheet1'.C2>),
#  (<Cell 'Sheet1'.A3>, <Cell 'Sheet1'.B3>, <Cell 'Sheet1'.C3>))

# %%
for rowOfCellObjects in sheet1['A1':'C3']:
    for cellObj in rowOfCellObjects:
        print(cellObj.coordinate, cellObj.value)
    print('--- END OF ROW ---')
# Out:
# A1 2015-04-05 13:34:02
# B1 Apples
# C1 73
# --- END OF ROW ---
# A2 2015-04-05 03:41:23
# B2 Cherries
# C2 85
# --- END OF ROW ---
# A3 2015-04-06 12:46:51
# B3 Pears
# C3 14
# --- END OF ROW ---

# %%
# To get access to cells in a particular row/column
sheet1.columns[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-ec5b9e8b1a52> in <module>
#       1 # To get access to cells in a particular row/column
# ----> 2 sheet1.columns[1]
#
# TypeError: 'generator' object is not subscriptable

# %%
for col in sheet1.iter_cols(min_row=1, max_col=3, max_row=7):
       for cell in col:
            print(cell)
            print(cell.value)
# Out:
# <Cell 'Sheet1'.A1>
# 2015-04-05 13:34:02
# <Cell 'Sheet1'.A2>
# 2015-04-05 03:41:23
# <Cell 'Sheet1'.A3>
# 2015-04-06 12:46:51
# <Cell 'Sheet1'.A4>
# 2015-04-08 08:59:43
# <Cell 'Sheet1'.A5>
# 2015-04-10 02:07:00
# <Cell 'Sheet1'.A6>
# 2015-04-10 18:10:37
# <Cell 'Sheet1'.A7>
# 2015-04-10 02:40:46
# <Cell 'Sheet1'.B1>
# Apples
# <Cell 'Sheet1'.B2>
# Cherries
# <Cell 'Sheet1'.B3>
# Pears
# <Cell 'Sheet1'.B4>
# Oranges
# <Cell 'Sheet1'.B5>
# Apples
# <Cell 'Sheet1'.B6>
# Bananas
# <Cell 'Sheet1'.B7>
# Strawberries
# <Cell 'Sheet1'.C1>
# 73
# <Cell 'Sheet1'.C2>
# 85
# <Cell 'Sheet1'.C3>
# 14
# <Cell 'Sheet1'.C4>
# 52
# <Cell 'Sheet1'.C5>
# 152
# <Cell 'Sheet1'.C6>
# 23
# <Cell 'Sheet1'.C7>
# 98

# %%
# Project: Reading Data from a Spreadsheet
wb = openpyxl.load_workbook('censuspopdata.xlsx')
#Step 1: Read the spreadsheet data
sheet_pop = wb.get_sheet_by_name("Population by Census Tract")
import pprint
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   after removing the cwd from sys.path.

# %%
countyData = {}
t = list(sheet1['A1':'D1000']) #unsure end so 100 suits
t = []

for col in sheet_pop.iter_rows(min_col=1, max_row=1000, max_col=4):
    for cell in col:
        t.append(cell.value)

new = [] #2d lists/arrays
n = int(len(t) / 4) #typecast
for i in range(n):
    new.append([0] * 4)

for i in range(n):
        new[i] = t[4 * i : 4 * i + 4]
  
    
temp = []
dict2 = {}
for i in range(1000):
    temp.append(new[i][:]) 
    d = dict([(a, (b, c, d)) for a, b, c, d in temp])
    dict2.update(d)
    temp = []
    
        

##OR 

countryData2 = {}
values = []
for row in range(2, 1000):
    # Each row in the spreadsheet has data for one census tract.
    state = sheet_pop['B' + str(row)].value
    county = sheet_pop['C' + str(row)].value
    pop = sheet_pop['D' + str(row)].value
    key = sheet_pop['A' + str(row)].value
    values.append([key, state, county, pop])#NEEDED
    #Not values = [key, state, county, pop]
    d = dict([(a, (b, c, d)) for a, b, c, d in values])
    countryData2.update(d)
    values = []

f = open("countryData.txt","w")
f.write( str(countryData) )
f.close()

# %%
#
dicts = {}
keys = range(4)
values = ["Hi", "I", "am", "John"]
for i in keys:
        dicts[i] = values[i]
print(dicts)
# Out:
# {0: 'Hi', 1: 'I', 2: 'am', 3: 'John'}

# %%
l = ['a', 'b', 'c', 'd', 'e', ' ']
d = dict([(k, v) for k,v in zip (l[::2], l[1::2])])
d
# Out:
# {'a': 'b', 'c': 'd', 'e': ' '}

# %%
#Chapter 12 
#Project
#Step 2: Populate the Data Structure
"""Goal: {'AK': {'Aleutians East': {'pop': 3141, 'tracts': 1},
'Aleutians West': {'pop': 5561, 'tracts': 2},
'Anchorage': {'pop': 291826, 'tracts': 55},
'Bethel': {'pop': 17013, 'tracts': 3},
'Bristol Bay':
--snip--
each state abbreviation will map to another dictionary
eahc country name will in turn map to a dictionary with just two keys, 
tracts and pop
Goal:
>>> countyData['AK']['Anchorage']['pop']
291826
>>> countyData['AK']['Anchorage']['tracts']
55
More genneratlly, the countryData keys will look like this: 
countyData[state abbrev][county]['tracts']
countyData[state abbrev][county]['pop']
"""
countryData2 = {}
values = []
for row in range(2, 1000):
    # Each row in the spreadsheet has data for one census tract.
    state = sheet_pop['B' + str(row)].value
    county = sheet_pop['C' + str(row)].value
    pop = sheet_pop['D' + str(row)].value
    # Make sure the key for this state exists.
    countryData2.setdefault(state, {})
    # Make sure the key for this county in this state exists.
    countryData2[state].setdefault(county, {'tracts': 0, 'pop': 0})
    # Each row represents one census tract, so increment by one.
    countryData2[state][county]['tracts'] += 1
    # Increase the county pop by the pop in this census tract.
    countryData2[state][county]['pop'] += int(pop)
    
f = open("countryData_part2.txt","w")
f.write( str(countryData) )
f.close()

# %%
countryData2
"""
The other code is there because you cannot add a county dictionary as
the value for a state abbreviation key until the key itself exists in countyData.
(That is, countyData['AK']['Anchorage']['tracts'] += 1 will cause an error if
the 'AK' key doesn’t exist yet.)
"""
# Out:
# "\nThe other code is there because you cannot add a county dictionary as\nthe value for a state abbreviation key until the key itself exists in countyData.\n(That is, countyData['AK']['Anchorage']['tracts'] += 1 will cause an error if\nthe 'AK' key doesn’t exist yet.)\n"

# %%
#Chapter 12
#Project
#Step 3: Write the Results to a File

countryData2 = {}
values = []
for row in range(2, 1000):
    # Each row in the spreadsheet has data for one census tract.
    state = sheet_pop['B' + str(row)].value
    county = sheet_pop['C' + str(row)].value
    pop = sheet_pop['D' + str(row)].value
    # Make sure the key for this state exists.
    countryData2.setdefault(state, {})
    # Make sure the key for this county in this state exists.
    countryData2[state].setdefault(county, {'tracts': 0, 'pop': 0})
    # Each row represents one census tract, so increment by one.
    countryData2[state][county]['tracts'] += 1
    # Increase the county pop by the pop in this census tract.
    countryData2[state][county]['pop'] += int(pop)
    
# Open a new text file and write the contents of countyData to it.
print('Writing results...')
resultFile = open('census2010.py', 'w')
resultFile.write('allData = ' + pprint.pformat(countryData2))
resultFile.close()
print('Done.')

"""The pprint.pformat() function produces a string that itself is formatted
as valid Python code. By outputting it to a text file named census2010.py,
you’ve generated a Python program from your Python program! This may
seem complicated, but the advantage is that you can now import census2010.py
just like any other Python module."""
# Out:
# Writing results...
# Done.
# 'The pprint.pformat() function produces a string that itself is formatted\nas valid Python code. By outputting it to a text file named census2010.py,\nyou’ve generated a Python program from your Python program! This may\nseem complicated, but the advantage is that you can now import census2010.py\njust like any other Python module.'

# %%
import os
import census2010
census2010.allData['AL']['Baldwin']
# Out:
# {'pop': 182265, 'tracts': 31}

# %%
Baldwin_pop = census2010.allData['AL']['Baldwin']['pop']
print("The 2010 population of Baldwin was " + str(Baldwin_pop))
# Out:
# The 2010 population of Baldwin was 182265

# %%
#Chapter 12
#Writing and Saving Excel Documents 
import openpyxl
wb = openpyxl.Workbook() #Create a new one
sheet = wb.get_active_sheet()
sheet.title = 'Spam Bacon Eggs Sheet'
print(wb.get_sheet_names())
#Must save documents
print()
wb = openpyxl.load_workbook('example.xlsx')
sheet = wb.get_active_sheet()
sheet.title = 'Spam Spam Spam'
wb.save('example_copy.xlsx') #Saving (save) excel file
# Out:
# ['Spam Bacon Eggs Sheet']
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated function get_active_sheet (Use the .active property).
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated function get_active_sheet (Use the .active property).
#   # This is added back by InteractiveShellApp.init_path()

# %%
#Chapter 12
#Creating and Removing sheets
wb = openpyxl.Workbook() #Create a new one
wb.create_sheet() #by default set to last sheet in workbook
print(wb.get_sheet_names())
print()
wb.create_sheet(index=0, title='First Sheet')
print(wb.get_sheet_names())
wb.create_sheet(index=2, title='Middle Sheet')
print()
print(wb.get_sheet_names())
#Removing (remove) excel sheets
wb.remove_sheet(wb.get_sheet_by_name('Middle Sheet'))
wb.remove_sheet(wb.get_sheet_by_name('Sheet1'))
print()
print(wb.get_sheet_names())
#Question: Why is it not saving
# Out:
# ['Sheet', 'Sheet1']
#
# ['First Sheet', 'Sheet', 'Sheet1']
#
# ['First Sheet', 'Sheet', 'Middle Sheet', 'Sheet1']
#
# ['First Sheet', 'Sheet']
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   del sys.path[0]
# ...

# %%
#Chapter 12
#Writing Values to Cells
wb = openpyxl.Workbook()
sheet = wb.get_sheet_by_name('Sheet')
sheet['a1'] = 'Hi!'
sheet['a1'].value
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   after removing the cwd from sys.path.
# 'Hi!'

# %%
#Chapter 12
#Project: Updating a Spreadsheet
wb = openpyxl.load_workbook("produceSales.xlsx")
#Step 1
"""The prices that you need to update are as follows:
Celery 1.19
Garlic 3.07
Lemon 1.27
You could write code like this:"""
sheet = wb.get_sheet_by_name('data')
# The produce types and their updated prices
PRICE_UPDATES = {'Garlic': 3.07,
                'Celery': 1.19,
                'Lemon': 1.27}

t = []
for row in range(2, 1000):
    produce = sheet['A' + str(row)].value
    if produce == 'Garlic':
        sheet['B' + str(row)] = PRICE_UPDATES.get('Garlic')
    elif produce == 'Celery':
        sheet['C' + str(row)] = PRICE_UPDATES.get('Celery')
    elif produce == 'Lemon':
        sheet['D' + str(row)] = PRICE_UPDATES.get('Lemon')
                
            
for rowOfCellObjects in sheet['A1':'D1000']:
    for cellObj in rowOfCellObjects:
        print(cellObj.value)
    print('--- END OF ROW ---')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   # Remove the CWD from sys.path while we load stuff.
# PRODUCE
# COST PER POUND
# POUNDS SOLD
# TOTAL
# --- END OF ROW ---
# Potatoes
# 0.86
# 21.6
# =ROUND(B2*C2,2)
# --- END OF ROW ---
# Okra
# 2.26
# 38.6
# =ROUND(B3*C3,2)
# --- END OF ROW ---
# Fava beans
# 2.69
# 32.800000000000004
# =ROUND(B4*C4,2)
# --- END OF ROW ---
# Watermelon
# 0.66
# 27.3
# =ROUND(B5*C5,2)
# --- END OF ROW ---
# Garlic
# 3.07
# 4.9
# =ROUND(B6*C6,2)
# --- END OF ROW ---
# Parsnips
# 2.27
# 1.1
# =ROUND(B7*C7,2)
# --- END OF ROW ---
# Asparagus
# 2.49
# 37.9
# =ROUND(B8*C8,2)
# --- END OF ROW ---
# Avocados
# 3.23
# 9.200000000000001
# =ROUND(B9*C9,2)
# --- END OF ROW ---
# Celery
# 3.07
# 1.19
# =ROUND(B10*C10,2)
# --- END OF ROW ---
# Okra
# 2.26
# 40
# =ROUND(B11*C11,2)
# --- END OF ROW ---
# Spinach
# 4.12
# 30
# =ROUND(B12*C12,2)
# ...

# %%
#Chapter 12
#Project 2
#Step 2: Check All Rows and Update Incorrect Prices
#Their version of above

# Loop through the rows and update the prices.
for rowNum in range(2, 1000): # skip the first row
    produceName = sheet.cell(row=rowNum, column=1).value
    if produceName in PRICE_UPDATES:
        sheet.cell(row=rowNum, column=2).value = PRICE_UPDATES[produceName]
wb.save('updatedProduceSales.xlsx')

# %%
#Chapter 12:
#Section on setting the font: but really not down for that
#Skipped

# %%
#Chapter 12
#Formulas
#sheet['B9'] = '=SUM(B1:B8)' stores =SUM(B1:B8) into B9
wbFormulas = openpyxl.Workbook()
sheet = wbFormulas.active
sheet['A1'] = 200
sheet['A2'] = 300
sheet['A3'] = '=SUM(A1:A2)'
sheet['A3'].value
wbFormulas.save('writeFormula.xlsx')

# %%
#Chapter 12
#Formulas pt 2
#To GET THE ACTUAL VALUE from it
#Use data only (values only) data_only
wbValuesOnly = openpyxl.load_workbook('writeFormula.xlsx', data_only = True)
sheet = wbValuesOnly.active
sheet['a3'].value
#unfortunately this does NOT work, and you need to 
#go to the file to change it and do a sort of 
#manual copy values only to make it 500 if want
sheet['a2'].value
# Out:
# 300

# %%
#Chapter 12
#Adjusting Rows and Columns
#Merging and Unmerging cells
#Merging cells
wb = openpyxl.Workbook()
sheet = wb.active
sheet.merge_cells('A1:D3')
sheet['A1'] = 'Twelve cells merged together.'
sheet.merge_cells('C5:D5')
sheet['C5'] = 'Two merged cells.'
wb.save('merged.xlsx')
#Unmerging cells
sheet.unmerge_cells('A1:D3')
sheet.merge_cells('C5:D5')
wb.save('merged.xlsx')

# %%
#Chapter 12
#Freeze and unfreeze panes
"""Table 12-3: Frozen Pane Examples
freeze_panes setting          Rows and columns frozen
sheet.freeze_panes = 'A2'     Row 1
sheet.freeze_panes = 'B1'     Column A
sheet.freeze_panes = 'C1'     Columns A and B
sheet.freeze_panes = 'C2'     Row 1 and columns A and B
sheet.freeze_panes = 'A1' or  No Frozen Pans
sheet.freeze_panes = None"""
# Out:
# "Table 12-3: Frozen Pane Examples\nfreeze_panes setting          Rows and columns frozen\nsheet.freeze_panes = 'A2'     Row 1\nsheet.freeze_panes = 'B1'     Column A\nsheet.freeze_panes = 'C1'     Columns A and B\nsheet.freeze_panes = 'C2'     Row 1 and columns A and B\nsheet.freeze_panes = 'A1' or  No Frozen Pans\nsheet.freeze_panes = None"

# %%
#Chapter 12
#Charts
#Skipping, maybe later, p complicated for easy task

# %%
#Chapter 12
#I built a function called blankrowinserter.py that can insert blank rows
#python blankrowinserter.py 3 2 example.xlsx
#this will insert two blank rows at row 3 (1 2 BLANK BLANK 5 6...) 
#for example.xlsx

# %%
#Chapter 13
#Working with Word Documents and PDF Documents
#Skipped
